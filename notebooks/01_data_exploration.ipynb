# %% [markdown]
# # 01 — Data Exploration
#
# **Zar3y — Crop Disease Detection**
#
# This notebook covers:
# 1. Loading the PlantVillage dataset (10 locked classes)
# 2. Visualizing class distribution
# 3. Displaying sample images per class
# 4. Previewing augmentation effects
# 5. Verifying the stratified 70/15/15 split (seed=42)

# %%
# TODO: Imports
# import os
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sns
# from PIL import Image

# %% [markdown]
# ## 1. Load Dataset & Class Distribution

# %%
# TODO: Load the 10 locked classes and count images per class

# %% [markdown]
# ## 2. Sample Images per Class

# %%
# TODO: Display a grid of sample images (3-5 per class)

# %% [markdown]
# ## 3. Augmentation Preview

# %%
# TODO: Show original vs augmented images side by side

# %% [markdown]
# ## 4. Split Verification

# %%
# TODO: Verify train/val/test split ratios and class balance
